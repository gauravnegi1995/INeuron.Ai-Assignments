# %% [markdown]
# # Assignment-3

# %% [raw]
# 1.1 Write a Python Program to implement your own myreduce() function which works exactly
# like Python's built-in function reduce()

# %%
import functools 
reduce=functools.reduce

# %%
l1=[1,2,3,4,5]

reduce(lambda x,y:x*y,l1)    #Reduce function
# Out:
# 120

# %%
values=[1,2,3,4,5]


def sum(a,b):
    return a+b


def mul(a,b):
    return a*b


def myreduce(func,x):
    
    a=0
    b=1
    
    for i in range(len(x)):
        if(b<len(x)):
            
            x[a]=func(x[a],x[b])
            
            b=b+1
           
            
    print(x[a])   
        
           


        
        
myreduce(mul,values)        #call method by passing function and values
# Out:
# 120

# %% [raw]
# 1.2 Write a Python program to implement your own myfilter() function which works exactly
# like Python's built-in function filter()

# %%
l1=[1,2,3,4,5]
list(filter(lambda x:x%2==0,l1))
# Out:
# [2, 4]

# %%
l1=[1,2,3,4,5,6,9,8]

def myfilter(function,values):
    
    for i in l1:
        
        if function(i) is True:
            print(i)
        
    
    
    
    
    
    
def div_by_2(X):
    if (X%2) is 0:
        return True
    else:
        return False
    
    
myfilter(div_by_2,l1)
# Out:
# 2
# 4
# 6
# 8

# %% [raw]
# Write List comprehensions to produce the following Lists ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]

# %%
word='ACADFILD'
l1=[]
for i in word:
    l1.append(i)
    
print(l1)
# Out:
# ['A', 'C', 'A', 'D', 'F', 'I', 'L', 'D']

# %% [raw]
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
item='xyz'
result=[i*item[j] for j in range(len(item)) for i in range(1,5)]
result
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %% [raw]
# 'x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
item='xyz'
result=[i*item[j] for i in range(1,5) 
        for j in range(len(item)) ]
result
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %% [raw]
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
l1=[2,3,4]

result=[[i+j] for j in range(3) for i in l1 ]
result
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %% [raw]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
l1=[2,3,4,5]

result=[[i+j for j in range(4) for i in l1 ]
result
# Out:
# [2, 3, 4, 5, 3, 4, 5, 6, 4, 5, 6, 7, 5, 6, 7, 8]

# %% [raw]
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %%
l1=[1,2,3]
result=[(i,j) for j in range(1,4) for i in l1]
result
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
