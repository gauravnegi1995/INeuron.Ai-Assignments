# %% [markdown]
# # ASSIGNMENT 2

# %% [raw]
# Create the below pattern using nested for loop in Python.
#
#
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print("*",end=" ")
    print("\n")
    
for i in range(5,0,-1):
    for j in range(1,i):
        print("*",end=" ")
    print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *

# %% [markdown]
# Write a Python program to reverse a word after accepting the input from the user. Input word: ineuron Output: norueni

# %%
a=input("enter value to be reversed: ")
print('Reversed value is : '+ a[::-1])
# Out:
# enter value to be reversed: gaurav
# Reversed value is : varuag
